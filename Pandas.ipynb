# %%
import pandas as pd

# %%
"""
Files :
    
    sample csv file - https://github.com/codeforamerica/ohana-api/tree/master/data/sample-csv
    Titanic - https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
    excel file - https://github.com/finbourne/sample-excel
"""

# %%
ls
# Out:
# LICENSE       customers.csv    help.txt    player-data.csv
# Pandas.ipynb  data/            notebooks/  products.csv
# README.md     dataFrame.ipynb  people.csv  requirements.txt

# %%
# pd.read_csv('locations.csv')
pd.read_csv('products.csv')
# Out:
#      Index                                    Name  \
# 0        1                 Thermostat Drone Heater
# 1        2   Ultra Speaker Iron Grill Advanced One
# 2        3                 Watch Headphones Kettle
# 3        4   Portable Toaster Clock Monitor Silent
# 4        5                        Pro Toaster Oven
# ..     ...                                     ...
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ..                                               ...
# 995            Piece the fight near never once bank.
# 996                 Apply drive outside reach apply.
# 997              Line cup course student each about.
# 998      History feel worry painting only power bad.
# 999                           Pay image either rest.
#
#                             Brand                Category  Price Currency  \
# 0                     Bradford-Yu      Kitchen Appliances     74      USD
# 1                   Douglas Group       Fitness Equipment    510      USD
# 2                   Landry-Austin  Beauty & Personal Care    254      USD
# 3         Odom, Norton and Foster                  Makeup     69      USD
# 4    Fowler, Mendoza and Mcdaniel              Automotive    525      USD
# ..                            ...                     ...    ...      ...
# 995                 Huffman Group            Toys & Games    903      USD
# 996                Woodward Group            Toys & Games      8      USD
# 997                Ramos-Cardenas  Beauty & Personal Care    615      USD
# 998                 Hooper-Bender          Men's Clothing    811      USD
# 999                    Campos Inc      Kitchen Appliances    867      USD
#
#      Stock            EAN             Color         Size   Availability  \
# 0      139  8619793560985            Orchid       Medium      backorder
# 1      351  3057216124300    MediumSeaGreen        Small      backorder
# 2      409  9825254410556          Lavender          XXL      pre_order
# 3      119  9490814777808              Pink           XL       in_stock
# 4      727  4726650403799        LightCoral           XL       in_stock
# ..     ...            ...               ...          ...            ...
# 995    737  8227581307423  MediumAquaMarine           XL  limited_stock
# 996    330   522633507294     PaleVioletRed       Medium   out_of_stock
# 997    630  1892829625606     PaleVioletRed  Extra Large      pre_order
# 998    566  1683591150065        LightGreen            S       in_stock
# 999    769  8697154897673         Gainsboro     50x70 cm  limited_stock
#
#      Internal ID
# 0             38
# 1             27
# 2              2
# 3             94
# 4             95
# ..           ...
# 995           33
# 996            9
# 997            4
# 998           65
# 999           10
#
# [1000 rows x 13 columns]

# %%
ds=pd.read_csv(r'products.csv')
ds["Price"] # this will give only price column
# Out:
# 0       74
# 1      510
# 2      254
# 3       69
# 4      525
#       ...
# 995    903
# 996      8
# 997    615
# 998    811
# 999    867
# Name: Price, Length: 1000, dtype: int64

# %%
ds(20) #if the column name is 20 you can use it like this

# %%
pd.read_csv(r'products.csv', header=None)
# Out:
#          0                                       1   \
# 0     Index                                    Name
# 1         1                 Thermostat Drone Heater
# 2         2   Ultra Speaker Iron Grill Advanced One
# 3         3                 Watch Headphones Kettle
# 4         4   Portable Toaster Clock Monitor Silent
# ...     ...                                     ...
# 996     996  Silent Router Phone Portable Automatic
# 997     997              Digital Treadmill Clean Go
# 998     998                  Wireless Vacuum Shaver
# 999     999  Portable Cooker Brush 360 Digital Mini
# 1000   1000          Smart Watch Edge Digital Sense
#
#                                                    2   \
# 0                                         Description
# 1              Consumer approach woman us those star.
# 2     Point suggest easy money operation could white.
# 3                            Reach husband education.
# 4               Always choose school poor table main.
# ...                                               ...
# 996             Piece the fight near never once bank.
# 997                  Apply drive outside reach apply.
# 998               Line cup course student each about.
# 999       History feel worry painting only power bad.
# 1000                           Pay image either rest.
#
#                            3                       4      5         6      7   \
# 0                       Brand                Category  Price  Currency  Stock
# 1                 Bradford-Yu      Kitchen Appliances     74       USD    139
# 2               Douglas Group       Fitness Equipment    510       USD    351
# 3               Landry-Austin  Beauty & Personal Care    254       USD    409
# 4     Odom, Norton and Foster                  Makeup     69       USD    119
# ...                       ...                     ...    ...       ...    ...
# 996             Huffman Group            Toys & Games    903       USD    737
# 997            Woodward Group            Toys & Games      8       USD    330
# 998            Ramos-Cardenas  Beauty & Personal Care    615       USD    630
# 999             Hooper-Bender          Men's Clothing    811       USD    566
# 1000               Campos Inc      Kitchen Appliances    867       USD    769
#
#                  8                 9            10             11           12
# 0               EAN             Color         Size   Availability  Internal ID
# 1     8619793560985            Orchid       Medium      backorder           38
# 2     3057216124300    MediumSeaGreen        Small      backorder           27
# 3     9825254410556          Lavender          XXL      pre_order            2
# 4     9490814777808              Pink           XL       in_stock           94
# ...             ...               ...          ...            ...          ...
# 996   8227581307423  MediumAquaMarine           XL  limited_stock           33
# 997   0522633507294     PaleVioletRed       Medium   out_of_stock            9
# 998   1892829625606     PaleVioletRed  Extra Large      pre_order            4
# 999   1683591150065        LightGreen            S       in_stock           65
# 1000  8697154897673         Gainsboro     50x70 cm  limited_stock           10
#
# [1001 rows x 13 columns]

# %%
pd.read_csv('people.csv')
# Out:
#     year  population
# 0   2000       12400
# 1   2001       12800
# 2   2002       13800
# 3   2003       13600
# 4   2004       14200
# 5   2005       15600
# 6   2006       17600
# 7   2007       19200
# 8   2008       20300
# 9   2009       20800
# 10  2010       21200
# 11  2011       22400
# 12  2012       23400
# 13  2013       24500
# 14  2014       25800
# 15  2015       26100
# 16  2016       28300
# 17  2017       29600
# 18  2018       32100
# 19  2019       32500
# 20  2020       33200
# 21  2021       33800

# %%
df = pd.read_csv('people.csv')

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
# LICENSE       README.md  demo.ipynb  notebooks/  products.csv
# Pandas.ipynb  data/      help.txt    people.csv  requirements.txt

# %%
pd.read_csv('people.csv',header=None)
# Out:
#        0           1
# 0   year  population
# 1   2000       12400
# 2   2001       12800
# 3   2002       13800
# 4   2003       13600
# 5   2004       14200
# 6   2005       15600
# 7   2006       17600
# 8   2007       19200
# 9   2008       20300
# 10  2009       20800
# 11  2010       21200
# 12  2011       22400
# 13  2012       23400
# 14  2013       24500
# 15  2014       25800
# 16  2015       26100
# 17  2016       28300
# 18  2017       29600
# 19  2018       32100
# 20  2019       32500
# 21  2020       33200
# 22  2021       33800

# %%
pd.read_csv('people.csv' ,names=["1st-Row" , "2nd-row"] )
# Out:
#    1st-Row     2nd-row
# 0     year  population
# 1     2000       12400
# 2     2001       12800
# 3     2002       13800
# 4     2003       13600
# 5     2004       14200
# 6     2005       15600
# 7     2006       17600
# 8     2007       19200
# 9     2008       20300
# 10    2009       20800
# 11    2010       21200
# 12    2011       22400
# 13    2012       23400
# 14    2013       24500
# 15    2014       25800
# 16    2015       26100
# 17    2016       28300
# 18    2017       29600
# 19    2018       32100
# 20    2019       32500
# 21    2020       33200
# 22    2021       33800

# %%
df=pd.read_csv('customers.csv')
# df.drop(['First Name','Country','Company'],axis=1)
df.pop('First Name')
df.pop('Country')
df.pop('Company')
# Out:
# 0                     Rasmussen Group
# 1                         Vega-Gentry
# 2                       Murillo-Perry
# 3     Dominguez, Mcmillan and Donovan
# 4            Martin, Lang and Andrade
#                    ...
# 95                          Carey LLC
# 96              Ware, Burns and Oneal
# 97                      Schmitt-Jones
# 98                 Fitzgerald-Harrell
# 99                 Le, Nash and Cross
# Name: Company, Length: 100, dtype: object

# %%
df = pd.read_csv('sample_test.csv',sep='|')

# %%
df
# Out:
#        name                 emailid    address  pin code         sirname
# 0  sudhanshu  SSKUMAR9876@GMAIL.COM  Bengalore     560085          kumar
# 1     krish         krish@gmail.com  bengalore     560085           naik
# 2    ineuron     ineuron@ineuron.ai  Bengalore     560085  intelligence
# 3     pandas      pandas@ineuron.ai    chennai   25845121       tutorial

# %%
pd.read_csv('sample_test.csv',sep='|' , skiprows=[1,3])
# Out:
#     name             emailid    address  pin code    sirname
# 0  krish     krish@gmail.com  bengalore     560085      naik
# 1  pandas  pandas@ineuron.ai    chennai   25845121  tutorial

# %%
df1 = pd.read_csv('sample_test.csv',sep='|' , skiprows=[1,3])

# %%
df1
# Out:
#     name             emailid    address  pin code    sirname
# 0  krish     krish@gmail.com  bengalore     560085      naik
# 1  pandas  pandas@ineuron.ai    chennai   25845121  tutorial

# %%
df = pd.read_csv('services.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# 15  16           16         NaN                       NaN
# 16  17           17         NaN                       NaN
# 17  18           18         NaN                       NaN
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                                application_process  \
# 0                     NaN                         Walk in or apply by phone.
# 1                     NaN                 Apply by phone for an appointment.
# 2                     NaN        Phone for information (403-4300 Ext. 4322).
# 3                     NaN                                    Apply by phone.
# 4                     NaN                             Phone for information.
# 5                     NaN  Walk in or apply by phone for membership appli...
# 6                     NaN  Apply by phone or be referred by a doctor, soc...
# 7                     NaN                                    Apply by phone.
# 8                     NaN  Walk in. Proof of residency in California requ...
# 9                     NaN  Walk in. Proof of California residency to rece...
# 10                    NaN  Walk in. Proof of California residency require...
# 11                    NaN  Walk in or apply by phone, email or webpage re...
# 12                    NaN  Walk in. Proof of California residency require...
# 13                    NaN  Call for appointment. Referral from human serv...
# 14                    NaN          Walk in or through other agency referral.
# 15                    NaN  Walk in. Written application, identification r...
# 16                    NaN                              Call for information.
# 17                    NaN  Call for screening appointment. Medical visits...
# 18                    NaN     Call for screening appointment (650-347-3648).
# 19                    NaN                                           Walk in.
# 20                    NaN                    By phone during business hours.
# 21  Fotos para pasaportes                  Walk in or apply by phone or mail
# 22                    NaN                  Walk in or apply by phone or mail
#
#                                              audience  \
# 0   Older adults age 55 or over, ethnic minorities...
# 1        Residents of San Mateo County age 55 or over
# 2   Older adults age 55 or over who can benefit fr...
# 3   Parents, children, families with problems of c...
# 4   Low-income working families with children tran...
# 5                                             Any age
# 6   Older adults who have memory or sensory loss, ...
# 7   Senior citizens age 60 or over, disabled indiv...
# 8      Ethnic minorities, especially Spanish speaking
# 9                                                 NaN
# 10                                                NaN
# 11  Adults, parents, children in 1st-12th grades i...
# 12                                                NaN
# 13  Individuals or families with low or no income ...
# 14  Adult alcoholic/drug addictive men and women w...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description  \
# 0   A walk-in center for older adults that provide...
# 1   Provides training and job placement to eligibl...
# 2   Offers supportive counseling services to San M...
# 3   Provides supervised visitation services and a ...
# 4   Provides fixed 8% short term loans to eligible...
# 5   A multipurpose center offering a wide variety ...
# 6   Rosener House is a day center for older adults...
# 7   Delivers a hot meal to the home of persons age...
# 8   Provides general reading material, including b...
# 9   Provides general reading and media materials, ...
# 10  Provides general reading materials, including ...
# 11  Offers an intergenerational literacy program f...
# 12  Provides general reading materials, including ...
# 13  Provides food, clothing, bus tokens and shelte...
# 14  Provides a long-term (6-12 month) residential ...
# 15  Provides emergency assistance including food a...
# 16  Provides emergency food, clothing and furnitur...
# 17  By appointment only, Project Smile provides a ...
# 18  Provides free medical and dental care to those...
# 19              no unrequired fields for this service
# 20                                just a test service
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                                           eligibility                  email  \
# 0   Age 55 or over for most programs, age 60 or ov...                    NaN
# 1   Age 55 or over, county resident and willing an...                    NaN
# 2         Resident of San Mateo County age 55 or over                    NaN
# 3                                                None                    NaN
# 4   Eligibility: Low-income family with legal cust...                    NaN
# 5                                                None                    NaN
# 6                                      Age 18 or over                    NaN
# 7             Homebound person unable to cook or shop                    NaN
# 8     Resident of California to obtain a library card                    NaN
# 9             Resident of California to obtain a card                    NaN
# 10  Resident of California to obtain a library car...                    NaN
# 11  English-speaking adult reading at or below 7th...                    NaN
# 12    Resident of California to obtain a library card                    NaN
# 13  None for most services. For emergency assistan...                    NaN
# 14  Age 21-60, detoxed, physically able and willin...                    NaN
# 15                      None for emergency assistance                    NaN
# 16                                Low-income families                    NaN
# 17    Low-income person without access to health care                    NaN
# 18    Low-income person without access to health care                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                               None  passports@example.org
# 22                                               None                    NaN
#
#     ...                            interpretation_services  \
# 0   ...                                                NaN
# 1   ...                                                NaN
# 2   ...                                                NaN
# 3   ...                                                NaN
# 4   ...                                                NaN
# 5   ...                                                NaN
# 6   ...                                                NaN
# 7   ...                                                NaN
# 8   ...                                                NaN
# 9   ...                                                NaN
# 10  ...                                                NaN
# 11  ...                                                NaN
# 12  ...                                                NaN
# 13  ...                                                NaN
# 14  ...                                                NaN
# 15  ...                                                NaN
# 16  ...                                                NaN
# 17  ...                                                NaN
# 18  ...                                                NaN
# 19  ...                                                NaN
# 20  ...                                                NaN
# 21  ...  We offer 3-way interpretation services over th...
# 22  ...                                                NaN
#
#                                              keywords languages  \
# 0   ADULT PROTECTION AND CARE SERVICES, Meal Sites...       NaN
# 1   EMPLOYMENT/TRAINING SERVICES, Job Development,...       NaN
# 2   Geriatric Counseling, Older Adults, Gay, Lesbi...       NaN
# 3   INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...       NaN
# 4      COMMUNITY SERVICES, Speakers, Automobile Loans       NaN
# 5   ADULT PROTECTION AND CARE SERVICES, In-Home Su...       NaN
# 6   ADULT PROTECTION AND CARE SERVICES, Adult Day ...       NaN
# 7   ADULT PROTECTION AND CARE SERVICES, Meal Sites...       NaN
# 8   EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 9   EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 10  EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 11  EDUCATION SERVICES, Adult, Alternative, Litera...       NaN
# 12  EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 13  COMMUNITY SERVICES, Interpretation/Translation...       NaN
# 14  ALCOHOLISM SERVICES, Residential Care, DRUG AB...       NaN
# 15  COMMODITY SERVICES, Clothing/Personal Items, C...       NaN
# 16  COMMODITY SERVICES, Clothing/Personal Items, C...       NaN
# 17  HEALTH SERVICES, Outpatient Care, Community Cl...       NaN
# 18  HEALTH SERVICES, Outpatient Care, Community Cl...       NaN
# 19                                                NaN       NaN
# 20                                                NaN       NaN
# 21                                    Salud, Medicina   Spanish
# 22         Ruby on Rails/Postgres/Redis, testing, wic       NaN
#
#                                     name  \
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# 22                  Example Service Name
#
#                           required_documents  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21  Government-issued picture identification
# 22                                       NaN
#
#                             service_areas    status  \
# 0                                   Colma    active
# 1                        San Mateo County    active
# 2                        San Mateo County    active
# 3                        San Mateo County    active
# 4                        San Mateo County    active
# 5                        San Mateo County    active
# 6     Belmont, Burlingame, East Palo Alto    active
# 7                 Belmont, East Palo Alto    active
# 8                        San Mateo County    active
# 9                        San Mateo County    active
# 10                       San Mateo County    active
# 11                              Daly City    active
# 12                       San Mateo County    active
# 13    Belmont, Burlingame, East Palo Alto    active
# 14       Alameda County, San Mateo County    active
# 15                                    NaN    active
# 16  Colma, Daly City, South San Francisco    active
# 17                         East Palo Alto    active
# 18                    Belmont, Burlingame    active
# 19                                    NaN   defunct
# 20                       San Mateo County  inactive
# 21       Alameda County, San Mateo County    active
# 22       San Mateo County, Alameda County    active
#
#                                             wait_time                 website  \
# 0                                            No wait.                     NaN
# 1                                             Varies.                     NaN
# 2                                             Varies.                     NaN
# 3                                            No wait.                     NaN
# 4                                                 NaN                     NaN
# 5                                            No wait.                     NaN
# 6                                            No wait.                     NaN
# 7                                            No wait.                     NaN
# 8                                            No wait.                     NaN
# 9                                            No wait.                     NaN
# 10                                           No wait.                     NaN
# 11  Depends on availability of tutors for small gr...                     NaN
# 12                                           No wait.                     NaN
# 13                                  Up to 20 minutes.                     NaN
# 14  Varies according to available beds for men and...                     NaN
# 15                                           No wait.                     NaN
# 16                                                NaN                     NaN
# 17                                            Varies.                     NaN
# 18                                            Varies.                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21                                No wait to 2 weeks.  http://www.example.com
# 22                                 No wait to 2 weeks  http://www.example.com
#
#                                 taxonomy_ids
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21  105, 108, 108-05, 108-05-01, 111, 111-05
# 22                                       NaN
#
# [23 rows x 22 columns]

# %%
df.head(2)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
#
#                   application_process  \
# 0          Walk in or apply by phone.
# 1  Apply by phone for an appointment.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
#
#                                          eligibility email  ...  \
# 0  Age 55 or over for most programs, age 60 or ov...   NaN  ...
# 1  Age 55 or over, county resident and willing an...   NaN  ...
#
#   interpretation_services                                           keywords  \
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
#
#   languages                              name required_documents  \
# 0       NaN   Fair Oaks Adult Activity Center                NaN
# 1       NaN  Second Career Employment Program                NaN
#
#       service_areas  status wait_time website taxonomy_ids
# 0             Colma  active  No wait.     NaN          NaN
# 1  San Mateo County  active   Varies.     NaN          NaN
#
# [2 rows x 22 columns]

# %%
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...        None
#
#                     email  ...  \
# 20                    NaN  ...
# 21  passports@example.org  ...
# 22                    NaN  ...
#
#                               interpretation_services  \
# 20                                                NaN
# 21  We offer 3-way interpretation services over th...
# 22                                                NaN
#
#                                       keywords languages  \
# 20                                         NaN       NaN
# 21                             Salud, Medicina   Spanish
# 22  Ruby on Rails/Postgres/Redis, testing, wic       NaN
#
#                                name                        required_documents  \
# 20  Service for Admin Test Location                                       NaN
# 21                  Passport Photos  Government-issued picture identification
# 22             Example Service Name                                       NaN
#
#                        service_areas    status            wait_time  \
# 20                  San Mateo County  inactive                  NaN
# 21  Alameda County, San Mateo County    active  No wait to 2 weeks.
# 22  San Mateo County, Alameda County    active   No wait to 2 weeks
#
#                    website                              taxonomy_ids
# 20                     NaN                                       NaN
# 21  http://www.example.com  105, 108, 108-05, 108-05-01, 111, 111-05
# 22  http://www.example.com                                       NaN
#
# [3 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# 15  16           16         NaN                       NaN
# 16  17           17         NaN                       NaN
# 17  18           18         NaN                       NaN
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                                application_process  \
# 0                     NaN                         Walk in or apply by phone.
# 1                     NaN                 Apply by phone for an appointment.
# 2                     NaN        Phone for information (403-4300 Ext. 4322).
# 3                     NaN                                    Apply by phone.
# 4                     NaN                             Phone for information.
# 5                     NaN  Walk in or apply by phone for membership appli...
# 6                     NaN  Apply by phone or be referred by a doctor, soc...
# 7                     NaN                                    Apply by phone.
# 8                     NaN  Walk in. Proof of residency in California requ...
# 9                     NaN  Walk in. Proof of California residency to rece...
# 10                    NaN  Walk in. Proof of California residency require...
# 11                    NaN  Walk in or apply by phone, email or webpage re...
# 12                    NaN  Walk in. Proof of California residency require...
# 13                    NaN  Call for appointment. Referral from human serv...
# 14                    NaN          Walk in or through other agency referral.
# 15                    NaN  Walk in. Written application, identification r...
# 16                    NaN                              Call for information.
# 17                    NaN  Call for screening appointment. Medical visits...
# 18                    NaN     Call for screening appointment (650-347-3648).
# 19                    NaN                                           Walk in.
# 20                    NaN                    By phone during business hours.
# 21  Fotos para pasaportes                  Walk in or apply by phone or mail
# 22                    NaN                  Walk in or apply by phone or mail
#
#                                              audience  \
# 0   Older adults age 55 or over, ethnic minorities...
# 1        Residents of San Mateo County age 55 or over
# 2   Older adults age 55 or over who can benefit fr...
# 3   Parents, children, families with problems of c...
# 4   Low-income working families with children tran...
# 5                                             Any age
# 6   Older adults who have memory or sensory loss, ...
# 7   Senior citizens age 60 or over, disabled indiv...
# 8      Ethnic minorities, especially Spanish speaking
# 9                                                 NaN
# 10                                                NaN
# 11  Adults, parents, children in 1st-12th grades i...
# 12                                                NaN
# 13  Individuals or families with low or no income ...
# 14  Adult alcoholic/drug addictive men and women w...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description  \
# 0   A walk-in center for older adults that provide...
# 1   Provides training and job placement to eligibl...
# 2   Offers supportive counseling services to San M...
# 3   Provides supervised visitation services and a ...
# 4   Provides fixed 8% short term loans to eligible...
# 5   A multipurpose center offering a wide variety ...
# 6   Rosener House is a day center for older adults...
# 7   Delivers a hot meal to the home of persons age...
# 8   Provides general reading material, including b...
# 9   Provides general reading and media materials, ...
# 10  Provides general reading materials, including ...
# 11  Offers an intergenerational literacy program f...
# 12  Provides general reading materials, including ...
# 13  Provides food, clothing, bus tokens and shelte...
# 14  Provides a long-term (6-12 month) residential ...
# 15  Provides emergency assistance including food a...
# 16  Provides emergency food, clothing and furnitur...
# 17  By appointment only, Project Smile provides a ...
# 18  Provides free medical and dental care to those...
# 19              no unrequired fields for this service
# 20                                just a test service
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...
# 22  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                                           eligibility                  email  \
# 0   Age 55 or over for most programs, age 60 or ov...                    NaN
# 1   Age 55 or over, county resident and willing an...                    NaN
# 2         Resident of San Mateo County age 55 or over                    NaN
# 3                                                None                    NaN
# 4   Eligibility: Low-income family with legal cust...                    NaN
# 5                                                None                    NaN
# 6                                      Age 18 or over                    NaN
# 7             Homebound person unable to cook or shop                    NaN
# 8     Resident of California to obtain a library card                    NaN
# 9             Resident of California to obtain a card                    NaN
# 10  Resident of California to obtain a library car...                    NaN
# 11  English-speaking adult reading at or below 7th...                    NaN
# 12    Resident of California to obtain a library card                    NaN
# 13  None for most services. For emergency assistan...                    NaN
# 14  Age 21-60, detoxed, physically able and willin...                    NaN
# 15                      None for emergency assistance                    NaN
# 16                                Low-income families                    NaN
# 17    Low-income person without access to health care                    NaN
# 18    Low-income person without access to health care                    NaN
# 19                                                NaN                    NaN
# 20                                                NaN                    NaN
# 21                                               None  passports@example.org
# 22                                               None                    NaN
#
#     ...                            interpretation_services  \
# 0   ...                                                NaN
# 1   ...                                                NaN
# 2   ...                                                NaN
# 3   ...                                                NaN
# 4   ...                                                NaN
# 5   ...                                                NaN
# 6   ...                                                NaN
# 7   ...                                                NaN
# 8   ...                                                NaN
# 9   ...                                                NaN
# 10  ...                                                NaN
# 11  ...                                                NaN
# 12  ...                                                NaN
# 13  ...                                                NaN
# 14  ...                                                NaN
# 15  ...                                                NaN
# 16  ...                                                NaN
# 17  ...                                                NaN
# 18  ...                                                NaN
# 19  ...                                                NaN
# 20  ...                                                NaN
# 21  ...  We offer 3-way interpretation services over th...
# 22  ...                                                NaN
#
#                                              keywords languages  \
# 0   ADULT PROTECTION AND CARE SERVICES, Meal Sites...       NaN
# 1   EMPLOYMENT/TRAINING SERVICES, Job Development,...       NaN
# 2   Geriatric Counseling, Older Adults, Gay, Lesbi...       NaN
# 3   INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...       NaN
# 4      COMMUNITY SERVICES, Speakers, Automobile Loans       NaN
# 5   ADULT PROTECTION AND CARE SERVICES, In-Home Su...       NaN
# 6   ADULT PROTECTION AND CARE SERVICES, Adult Day ...       NaN
# 7   ADULT PROTECTION AND CARE SERVICES, Meal Sites...       NaN
# 8   EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 9   EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 10  EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 11  EDUCATION SERVICES, Adult, Alternative, Litera...       NaN
# 12  EDUCATION SERVICES, Library, Libraries, Public...       NaN
# 13  COMMUNITY SERVICES, Interpretation/Translation...       NaN
# 14  ALCOHOLISM SERVICES, Residential Care, DRUG AB...       NaN
# 15  COMMODITY SERVICES, Clothing/Personal Items, C...       NaN
# 16  COMMODITY SERVICES, Clothing/Personal Items, C...       NaN
# 17  HEALTH SERVICES, Outpatient Care, Community Cl...       NaN
# 18  HEALTH SERVICES, Outpatient Care, Community Cl...       NaN
# 19                                                NaN       NaN
# 20                                                NaN       NaN
# 21                                    Salud, Medicina   Spanish
# 22         Ruby on Rails/Postgres/Redis, testing, wic       NaN
#
#                                     name  \
# 0        Fair Oaks Adult Activity Center
# 1       Second Career Employment Program
# 2                 Senior Peer Counseling
# 3               Family Visitation Center
# 4      Economic Self-Sufficiency Program
# 5   Little House Recreational Activities
# 6       Rosener House Adult Day Services
# 7         Meals on Wheels - South County
# 8                       Fair Oaks Branch
# 9                           Main Library
# 10                       Schaberg Branch
# 11                          Project Read
# 12                 Redwood Shores Branch
# 13                    Redwood City Corps
# 14           Adult Rehabilitation Center
# 15                       Sunnyvale Corps
# 16     South San Francisco Citadel Corps
# 17                         Project Smile
# 18         San Mateo Free Medical Clinic
# 19             Service with blank fields
# 20       Service for Admin Test Location
# 21                       Passport Photos
# 22                  Example Service Name
#
#                           required_documents  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21  Government-issued picture identification
# 22                                       NaN
#
#                             service_areas    status  \
# 0                                   Colma    active
# 1                        San Mateo County    active
# 2                        San Mateo County    active
# 3                        San Mateo County    active
# 4                        San Mateo County    active
# 5                        San Mateo County    active
# 6     Belmont, Burlingame, East Palo Alto    active
# 7                 Belmont, East Palo Alto    active
# 8                        San Mateo County    active
# 9                        San Mateo County    active
# 10                       San Mateo County    active
# 11                              Daly City    active
# 12                       San Mateo County    active
# 13    Belmont, Burlingame, East Palo Alto    active
# 14       Alameda County, San Mateo County    active
# 15                                    NaN    active
# 16  Colma, Daly City, South San Francisco    active
# 17                         East Palo Alto    active
# 18                    Belmont, Burlingame    active
# 19                                    NaN   defunct
# 20                       San Mateo County  inactive
# 21       Alameda County, San Mateo County    active
# 22       San Mateo County, Alameda County    active
#
#                                             wait_time                 website  \
# 0                                            No wait.                     NaN
# 1                                             Varies.                     NaN
# 2                                             Varies.                     NaN
# 3                                            No wait.                     NaN
# 4                                                 NaN                     NaN
# 5                                            No wait.                     NaN
# 6                                            No wait.                     NaN
# 7                                            No wait.                     NaN
# 8                                            No wait.                     NaN
# 9                                            No wait.                     NaN
# 10                                           No wait.                     NaN
# 11  Depends on availability of tutors for small gr...                     NaN
# 12                                           No wait.                     NaN
# 13                                  Up to 20 minutes.                     NaN
# 14  Varies according to available beds for men and...                     NaN
# 15                                           No wait.                     NaN
# 16                                                NaN                     NaN
# 17                                            Varies.                     NaN
# 18                                            Varies.                     NaN
# 19                                                NaN                     NaN
# 20                                                NaN                     NaN
# 21                                No wait to 2 weeks.  http://www.example.com
# 22                                 No wait to 2 weeks  http://www.example.com
#
#                                 taxonomy_ids
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21  105, 108, 108-05, 108-05-01, 111, 111-05
# 22                                       NaN
#
# [23 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
a = df["name"]

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
df1 = df[["name" ,'location_id','id' ]]

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['name']])
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is FA55-E833
#
#  Directory of C:\Users\win10\jupyter\Complete Python Module-20210227T092441Z-001\Complete Python Module\16-17. Pandas-Numpy
#
# 02/26/2022  01:00 PM    <DIR>          .
# 02/26/2022  01:00 PM    <DIR>          ..
# 02/26/2022  11:49 AM    <DIR>          .ipynb_checkpoints
# 07/07/2021  08:04 PM           107,005 16.1 Pandas file read and write operation.ipynb
# 06/01/2021  06:38 AM           138,431 16.2 Pandas data manipulation .ipynb
# 06/01/2021  06:38 AM           105,034 16.3 Pandas data manipulation_continue .ipynb
# 07/07/2021  08:04 PM            94,904 17. Numpy in details.ipynb
# 02/26/2022  12:05 PM             1,173 addresses.csv
# 02/26/2022  12:05 PM             1,589 contacts.csv
# 04/11/2021  06:07 AM    <DIR>          example_files
# 02/26/2022  12:05 PM               277 holiday_schedules.csv
# 02/26/2022  12:05 PM            18,015 locations.csv
# 02/26/2022  01:00 PM           161,651 LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx
# 02/26/2022  01:00 PM           161,410 LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx
# 02/26/2022  01:00 PM            71,993 LUSID Excel - Manage Orders.xlsx
# 02/26/2022  01:00 PM           137,753 LUSID Excel - Manage your investment strategies.xlsx
# 02/26/2022  01:00 PM           184,013 LUSID Excel - Setting up your IBOR.xlsx
# 02/26/2022  01:00 PM           136,632 LUSID Excel - Setting up your market data.xlsx
# 02/26/2022  12:05 PM             1,610 mail_addresses.csv
# 08/07/2020  11:06 PM                 0 my_database4.db
# 08/07/2020  11:07 PM             8,192 my_database5.db
# 08/08/2020  03:48 AM           189,104 mydata.h5
# 08/07/2020  11:06 PM             8,192 mydata2.sqlite
# 11/06/2021  09:38 PM            39,413 Numpy.ipynb
# 02/26/2022  12:05 PM             2,281 organizations.csv
# 10/10/2021  10:11 PM           263,960 pandas data manupulation.ipynb
# 02/26/2022  12:54 PM           226,444 Pandas.ipynb
# 02/26/2022  12:05 PM             2,092 phones.csv
# 02/26/2022  12:05 PM                60 programs.csv
# 02/26/2022  12:05 PM               350 regular_schedules.csv
# 02/26/2022  12:31 PM               254 sample_test.csv
# 02/26/2022  12:05 PM            19,128 services.csv
# 02/26/2022  12:17 PM            14,578 taxonomy.csv
# 11/06/2021  10:19 PM             5,122 Untitled1.ipynb
#               30 File(s)      2,100,660 bytes
#                4 Dir(s)  471,003,660,288 bytes free

# %%
pd.read_excel('LUSID Excel - Manage Orders.xlsx',sheet_name = "Allocations")
# Out:
#     Unnamed: 0                                    Unnamed: 1       Unnamed: 2  \
# 0          NaN  This sheet allows you to manage Allocations:              NaN
# 1          NaN                            1. ListAllocations              NaN
# 2          NaN                              2. GetAllocation              NaN
# 3          NaN                          3. UpsertAllocations              NaN
# 4          NaN                                           NaN              NaN
# ..         ...                                           ...              ...
# 60         NaN                                           NaN              NaN
# 61         NaN                                           NaN              NaN
# 62         NaN                                           NaN             Code
# 63         NaN                                           NaN  MyAllocation001
# 64         NaN                                           NaN  MyAllocation002
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# ..        ...        ...        ...        ...        ...        ...
# 60        NaN        NaN        NaN        NaN        NaN        NaN
# 61        NaN        NaN        NaN        NaN        NaN        NaN
# 62        NaN        NaN        NaN        NaN        NaN        NaN
# 63        NaN        NaN        NaN        NaN        NaN        NaN
# 64        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 9  ... Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 0         NaN  ...         NaN         NaN         NaN         NaN
# 1         NaN  ...         NaN         NaN         NaN         NaN
# 2         NaN  ...         NaN         NaN         NaN         NaN
# 3         NaN  ...         NaN         NaN         NaN         NaN
# 4         NaN  ...         NaN         NaN         NaN         NaN
# ..        ...  ...         ...         ...         ...         ...
# 60        NaN  ...         NaN         NaN         NaN         NaN
# 61        NaN  ...         NaN         NaN         NaN         NaN
# 62        NaN  ...         NaN         NaN         NaN         NaN
# 63        NaN  ...         NaN         NaN         NaN         NaN
# 64        NaN  ...         NaN         NaN         NaN         NaN
#
#    Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 60         NaN         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN         NaN
# 62         NaN         NaN         NaN         NaN         NaN         NaN
# 63         NaN         NaN         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN         NaN         NaN
#
# [65 rows x 25 columns]

# %%
df = pd.read_excel('LUSID Excel - Manage Orders.xlsx')

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
df = pd.ExcelFile('LUSID Excel - Manage Orders.xlsx')

# %%
df.sheet_names
# Out:
# ['Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    pd.read_excel('LUSID Excel - Manage Orders.xlsx' , sheet_name=i)

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/phones.csv')
# Out:
#     id  contact_id  location_id  organization_id  service_id  country_prefix  \
# 0    1         NaN          1.0              NaN         NaN             NaN
# 1    2         NaN          1.0              NaN         NaN             NaN
# 2    3         NaN          2.0              NaN         NaN             NaN
# 3    4         NaN          2.0              NaN         NaN             NaN
# 4    5         NaN          3.0              NaN         NaN             NaN
# 5    6         NaN          3.0              NaN         NaN             NaN
# 6    7         NaN          4.0              NaN         NaN             NaN
# 7    8         NaN          4.0              NaN         NaN             NaN
# 8    9         NaN          5.0              NaN         NaN             NaN
# 9   10         NaN          5.0              NaN         NaN             NaN
# 10  11         NaN          6.0              NaN         NaN             NaN
# 11  12         NaN          6.0              NaN         NaN             NaN
# 12  13         NaN          7.0              NaN         NaN             NaN
# 13  14         NaN          7.0              NaN         NaN             NaN
# 14  15         NaN          8.0              NaN         NaN             NaN
# 15  16         NaN          8.0              NaN         NaN             NaN
# 16  17         NaN          9.0              NaN         NaN             NaN
# 17  18         NaN          9.0              NaN         NaN             NaN
# 18  19         NaN         10.0              NaN         NaN             NaN
# 19  20         NaN         10.0              NaN         NaN             NaN
# 20  21         NaN         11.0              NaN         NaN             NaN
# 21  23         NaN         12.0              NaN         NaN             NaN
# 22  24         NaN         12.0              NaN         NaN             NaN
# 23  25         NaN         13.0              NaN         NaN             NaN
# 24  26         NaN         14.0              NaN         NaN             NaN
# 25  27         NaN         14.0              NaN         NaN             NaN
# 26  28         NaN         15.0              NaN         NaN             NaN
# 27  29         NaN         15.0              NaN         NaN             NaN
# 28  30         NaN         16.0              NaN         NaN             NaN
# 29  31         NaN         16.0              NaN         NaN             NaN
# 30  32         NaN         17.0              NaN         NaN             NaN
# 31  33         NaN         17.0              NaN         NaN             NaN
# 32  34         NaN         17.0              NaN         NaN             NaN
# 33  35         NaN         18.0              NaN         NaN             NaN
# 34  36         NaN         18.0              NaN         NaN             NaN
# 35  37         NaN         19.0              NaN         NaN             NaN
# 36  38         NaN         19.0              NaN         NaN             NaN
# 37  39         NaN         21.0              NaN         NaN             NaN
# 38  40         NaN         21.0              NaN         NaN             NaN
# 39  41        29.0          NaN              NaN         NaN             1.0
# 40  42        29.0          NaN              NaN         NaN             1.0
# 41  43         NaN         22.0              NaN         NaN             NaN
# 42  44         NaN         22.0              NaN         NaN             NaN
# 43  45         NaN         22.0              NaN         NaN             NaN
# 44  46         NaN         22.0              NaN         NaN             NaN
# 45  52        36.0          NaN              NaN         NaN             NaN
# 46  53         NaN          NaN              8.0         NaN             NaN
# 47  54        32.0          NaN              NaN         NaN             NaN
# 48  55        32.0          NaN              NaN         NaN             NaN
# 49  56         NaN         11.0              NaN         NaN             NaN
# 50  57         NaN          NaN              NaN        22.0             NaN
# 51  58         NaN          NaN              NaN        22.0             NaN
# 52  59         NaN          NaN              NaN        22.0             NaN
# 53  60        29.0          NaN              NaN         NaN             NaN
#
#                department  extension        number number_type vanity_number
# 0                     NaN        NaN  650 780-7525       voice           NaN
# 1                     NaN        NaN  650 701-0856         fax           NaN
# 2                     NaN     4385.0  650 403-4300       voice           NaN
# 3                     NaN        NaN  650 403-4302         fax           NaN
# 4                 English        NaN  650 403-4300       voice           NaN
# 5                     NaN        NaN  650 403-4303         fax           NaN
# 6                     NaN     4500.0  650 403-4300       voice           NaN
# 7                     NaN        NaN  650 403-4303         fax           NaN
# 8                     NaN     4100.0  650 403-4300       voice           NaN
# 9                     NaN        NaN  650 403-4303         fax           NaN
# 10                    NaN        NaN  650 326-2025       voice           NaN
# 11                    NaN        NaN  650 326-9547         fax           NaN
# 12                    NaN        NaN  650 322-0126       voice           NaN
# 13                    NaN        NaN  650 322-4067         fax           NaN
# 14                    NaN        NaN  650 323-2022       voice           NaN
# 15                    NaN        NaN  650 326-9547         fax           NaN
# 16                    NaN        NaN  650 780-7261       voice           NaN
# 17                    NaN        NaN  650 569-3371         fax           NaN
# 18            Circulation        NaN  650 780-7018       voice           NaN
# 19                    NaN        NaN  650 780-7069         fax           NaN
# 20                    NaN        NaN  650 780-7010       voice           NaN
# 21                    NaN        NaN  650 780-7077       voice           NaN
# 22                    NaN        NaN  650 780-7004         fax           NaN
# 23                    NaN        NaN  650 780-5740       voice           NaN
# 24                    NaN        NaN  650 368-4643       voice           NaN
# 25                    NaN        NaN  650 364-1712         fax           NaN
# 26                    NaN        NaN  415 643-8000       voice           NaN
# 27                    NaN        NaN  415 285-1391         fax           NaN
# 28                    NaN        NaN  408 720-0420       voice           NaN
# 29                    NaN        NaN  408 720-8075         fax           NaN
# 30                    NaN        NaN  650 266-4591       voice           NaN
# 31                    NaN        NaN  650 266-2594         fax           NaN
# 32                    NaN        NaN  650 266-4594         fax           NaN
# 33                    NaN        NaN  650 839-1447       voice           NaN
# 34                    NaN        NaN  650 839-1457         fax           NaN
# 35                    NaN        NaN  650 578-0400       voice           NaN
# 36                    NaN        NaN  650 578-0440         fax           NaN
# 37               CalFresh     1223.0    7035551212       voice  703-555-ABCD
# 38               CalFresh        NaN    2025551212         fax           NaN
# 39              Referrals     1200.0  123-456-7890       voice           NaN
# 40              Referrals        NaN  202-555-1212         fax           NaN
# 41            Information      123.0  650 372-6200       voice  222-555-INFO
# 42           Reservations        NaN  650 627-8244         fax           NaN
# 43                Hotline        NaN  800 372-6200     hotline           NaN
# 44      Rental Assistance      202.0  650 372-6200         tty           NaN
# 45  CalFresh Applications      123.0  703-555-1212       voice           NaN
# 46             Operations      101.0  123-456-7890       voice           NaN
# 47             Operations        NaN  703-444-1234         fax           NaN
# 48             Operations      101.0  650-555-1212       voice           NaN
# 49                    NaN        NaN  650 365-3738         fax           NaN
# 50        Passport Photos      123.0  123-456-7890       voice           NaN
# 51    Passport Photos Fax        NaN  789-456-1230         fax           NaN
# 52  Passport Help via SMS        NaN  650-222-5555         sms           NaN
# 53                    NaN        NaN  650-555-1212         sms           NaN

# %%
pd.read_csv('player-data.csv')
# Out:
#     player_id     version                                  name  \
# 0      239085  2024-03-27                 Erling Braut Håland -
# 1      231747  2024-03-27                Kylian Mbappé Lottin -
# 2      192985  2024-03-27                     Kevin De Bruyne -
# 3      231866  2024-03-27                               Rodri -
# 4      202126  2024-03-27                   Harry Edward Kane -
# 5      192119  2024-03-27       Thibaut Nicolas Marc Courtois -
# 6      188545  2024-03-27                  Robert Lewandowski -
# 7      158023  2024-03-27       Lionel Andrés Messi Cuccitini -
# 8      239818  2024-03-27                          Rúben Dias -
# 9      238794  2024-03-27                            Vini Jr. -
# 10     212831  2024-03-27                             Alisson -
# 11     209331  2024-03-27           Mohamed Salah Hamed Ghaly -
# 12     203376  2024-03-27                     Virgil van Dijk -
# 13     192448  2024-03-27               Marc-André ter Stegen -
# 14     190871  2024-03-27                           Neymar Jr -
# 15     165153  2024-03-27                       Karim Benzema -
# 16     252371  2024-03-27      Jude Victor William Bellingham -
# 17     239053  2024-03-27  Federico Santiago Valverde Dipetta -
# 18     231478  2024-03-27             Lautaro Javier Martínez -
# 19     218667  2024-03-27                      Bernardo Silva -
# 20     210257  2024-03-27                             Ederson -
# 21     200389  2024-03-27                           Jan Oblak -
# 22     194765  2024-03-27                   Antoine Griezmann -
# 23     256630  2024-03-27               Florian Richard Wirtz -
# 5   1992-05-11         GK  ...         66                   20
# 6   1988-08-21         ST  ...         88                   35
# 7   1987-06-24     CF,CAM  ...         96                   20
# 8   1997-05-14         CB  ...         81                   91
# 9   2000-07-12      LW,ST  ...         79                   32
# 10  1992-10-02         GK  ...         66                   15
# 11  1992-06-15         RW  ...         90                   38
# 12  1991-07-08         CB  ...         89                   90
# 13  1992-04-30         GK  ...         70                   25
# 14  1992-02-05     LW,CAM  ...         93                   35
# 15  1987-12-19      CF,ST  ...         90                   43
# 16  2003-06-29     CAM,CM  ...         85                   77
# 17  1998-07-22      CM,RW  ...         84                   79
# 18  1997-08-22         ST  ...         88                   55
# 19  1994-08-10      CM,RW  ...         89                   70
# 20  1993-08-17         GK  ...         70                   29
# 21  1993-01-07         GK  ...         68                   27
# 22  1991-03-21         ST  ...         89                   45
# 23  2003-05-03        CAM  ...         84                   58
# 24  1997-12-06         GK  ...         66                   15
# 25  1999-01-14     CDM,CM  ...         83                   85
# 26  1998-12-29         ST  ...         80                   36
# 27  1999-02-25         GK  ...         65                   20
# 28  1997-05-12     CM,CDM  ...         90                   76
# 29  1998-12-17     CAM,CM  ...         87                   67
# 30  1995-07-03         GK  ...         68                   23
# 31  1995-02-08  CDM,RB,CM  ...         86                   81
# 32  1994-09-08     CM,CAM  ...         79                   62
# 33  1994-05-14         CB  ...         86                   90
# 34  1992-07-08   LW,LM,ST  ...         88                   47
# 35  1985-09-09     CM,CAM  ...         92                   70
# 36  1986-03-27         GK  ...         70                   17
# 37  2003-02-26  CAM,LM,CM  ...         84                   64
# 38  1999-03-07      CB,RB  ...         76                   86
# 39  2002-11-25      CM,LW  ...         87                   68
# 40  2001-02-12      LW,RW  ...         79                   38
# 41  2001-09-05      RW,RM  ...         81                   60
# 42  1999-06-10   LW,CF,LM  ...         83                   22
# 43  1998-01-18         CB  ...         74                   86
# 44  2000-05-28  LW,RW,CAM  ...         86                   60
# 45  1997-11-14  CF,CAM,ST  ...         81                   62
# 46  1997-05-15         RW  ...         81                   42
# 47  1998-10-07         RB  ...         82                   78
# 48  1997-02-07         CM  ...         86                   80
# 49  1995-02-27     CM,CDM  ...         84                   77
# 50  1996-01-11      RM,LM  ...         83                   36
# 51  1994-03-11         LB  ...         83                   83
# 52  1993-11-15  CF,CAM,ST  ...         84                   32
# 53  1994-05-27   RB,LB,RM  ...         85                   79
# 54  1995-09-20     LWB,LM  ...         83                   76
# 55  1994-02-08     CM,CDM  ...         85                   74
# 56  1991-02-21      RM,RW  ...         81                   45
# 57  1992-09-02         GK  ...         62                   11
# 58  1992-02-23        CDM  ...         81                   86
# 59  1990-10-24     CM,CDM  ...         87                   77
#
#    standing_tackle sliding_tackle gk_diving gk_handling  gk_kicking  \
# 0               47             29         7          14          13
# 1               34             32        13           5           7
# 2               70             53        15          13           5
# 3               87             78        10          10           7
# 4               46             38         8          10          11
# 5               18             16        85          89          76
# 6               42             19        15           6          12
# 7               35             24         6          11          15
# 8               91             87         7           8          13
# 9               25             18         5           7           7
# 10              19             16        86          85          85
# 11              43             41        14          14           9
# 12              91             86        13          10          13
# 13              13             10        86          85          89
# 14              32             29         9           9          15
# 15              24             18        13          11           5
# 16              79             77        14          11          10
# 17              85             79         6          10           6
# 18              31             44        11           8           8
# 19              76             60         9          10          14
# 20              15              8        87          82          91
# 21              14             18        85          90          78
# 22              63             64        14           8          14
# 23              49             44        14          14          13
# 24              15             15        86          84          73
# 25              86             85         8          11          14
# 26              45             22        14          14          10
# 27              14             16        90          81          73
# 28              76             77         7          13          10
# 29              59             57        14          15          15
# 30              16             19        85          82          87
# 31              84             78         8          15           7
# 32              71             63        12          14          15
# 33              89             88         6           6          12
# 34              34             33        11          13          13
# 35              73             72        13           9           7
# 36              10             11        84          85          90
# 37              63             68         6           9           8
# 38              86             86        11          14           9
# 39              77             65        12           7          11
# 40              39             34         9          15           8
# 41              62             60         7           8          13
# 42              24             21        10          12          15
# 43              87             85        11           8          15
# 44              59             47         8          15           6
# 45              64             54         5           6          10
# 46              30             33         6           6          14
# 47              82             78        14          15          14
# 48              83             81        11           5          13
# 49              77             79         7          10           7
# 50              32             35         8          12           9
# 51              83             81        11           8          10
# 52              41             39         5           4           4
# 53              83             79         6           9          15
# 54              78             74         7          13          10
# 55              74             65         9          14          11
# 56              34             22        15           9          13
# 57              20             20        84          82          83
# 58              87             87        13          14          16
# 59              75             67        11          14           5
#
#     gk_positioning gk_reflexes  \
# 0               11           7
# 1               11           6
# 2               10          13
# 3               14           8
# 4               14          11
# 5               90          93
# 6                8          10
# 7               14           8
# 8                7          12
# 9                7          10
# 10              90          89
# 11              11          14
# 12              11          11
# 13              86          91
# 14              15          11
# 15               5           7
# 16               5           8
# 17              15           8
# 18               8          13
# 19              12           9
# 20              86          87
# 21              86          87
# 22              13          14
# 23               6          10
# 24              86          89
# 25               5           9
# 26               9           6
# 27              83          89
# 28              10           9
# 29               8          10
# 30              85          89
# 31              15          15
# 32               8          14
# 33              10          13
# 34               6          10
# 35              14           9
# 36              88          84
# 37               8          11
# 38              11           8
# 39               8           8
# 40              14           8
# 41               9          13
# 42              11           9
# 43              12          15
# 44              10          13
# 45              15           7
# 46              10          13
# 47               6           7
# 48              14          11
# 49              16           7
# 50               9          14
# 51               7          14
# 52               5           8
# 53              14          14
# 54               7          13
# 55               6          10
# 56              11           6
# 57              85          85
# 58              12          12
# 59               5          13
#
#                                           play_styles
# 0                 Acrobatic +,Power Header,Quick Step
# 1   Quick Step +,Finesse Shot,Rapid,Flair,Trivela,...
# 2   Incisive Pass +,Dead Ball,Pinged Pass,Long Bal...
# 3   Power Shot +,Long Ball Pass,Bruiser,Aerial,Lon...
# 4   Incisive Pass +,Long Ball Pass,First Touch,Tri...
# 5                             Far Throw,Cross Claimer
# 6   Power Header +,Finesse Shot,Chip Shot,Power Sh...
# 7   Technical +,Finesse Shot,Dead Ball,Incisive Pa...
# 8             Bruiser +,Power Header,Block,Leadership
# 9   Quick Step +,Finesse Shot,Chip Shot,Rapid,Flai...
# 10                   Far Throw,Cross Claimer,Rush Out
# 11             Finesse Shot +,Chip Shot,Rapid,Trivela
# 12  Aerial +,Power Header,Long Ball Pass,Jockey,Bl...
# 13                    Footwork,Cross Claimer,Rush Out
# 14  Trickster +,Incisive Pass,Technical,Flair,Firs...
# 15  First Touch +,Finesse Shot,Incisive Pass,Tiki ...
# 16  Relentless +,Intercept,Slide Tackle,Technical,...
# 17  Power Shot,Long Ball Pass,Rapid,Relentless,Tri...
# 18                            Technical,Flair,Trivela
# 19  Technical +,Tiki Taka,Flair,Relentless,Trivela...
# 20              Long Ball Pass,Cross Claimer,Rush Out
# 21                            Far Throw,Cross Claimer
# 22  Finesse Shot +,Chip Shot,Incisive Pass,Technic...
# 23  Chip Shot,Incisive Pass,Technical,Flair,First ...
# 24  Far Throw,Footwork,Cross Claimer,Rush Out,Lead...
# 25  Long Ball Pass,Block,Intercept,Press Proven,Lo...
# 26             Chip Shot,Power Header,Rapid,Acrobatic
# 27                             Cross Claimer,Rush Out
# 28  Trivela +,Incisive Pass,Long Ball Pass,Tiki Ta...
# 29  Incisive Pass +,Pinged Pass,Whipped Cross,Tech...
# 30                 Far Throw,Cross Claimer,Leadership
# 31  Long Ball Pass +,Whipped Cross,Press Proven,Re...
# 32  Pinged Pass +,Incisive Pass,Long Ball Pass,Fla...
# 33  Intercept +,Power Header,Jockey,Anticipate,Aer...
# 34  Finesse Shot +,Rapid,Quick Step,Long Shot Take...
# 35  Trivela +,Incisive Pass,Long Ball Pass,Whipped...
# 36  Pinged Pass,Far Throw,Cross Claimer,Rush Out,I...
# 37  Technical +,Flair,First Touch,Trickster,Long S...
# 38  Block +,Power Header,Jockey,Anticipate,Slide T...
# 39  Tiki Taka +,Incisive Pass,Long Ball Pass,Techn...
# 40  Trickster +,Finesse Shot,Incisive Pass,Whipped...
# 41                       Finesse Shot,Technical,Flair
# 42  Rapid +,Finesse Shot,Whipped Cross,Flair,Trick...
# 43  Power Header,Long Ball Pass,Block,Intercept,Ae...
# 44                      First Touch +,Technical,Flair
# 45  Finesse Shot,Incisive Pass,Technical,Flair,Fir...
# 46    Rapid +,Flair,Trickster,Quick Step,Injury Prone
# 47  Long Ball Pass +,Dead Ball,Incisive Pass,Whipp...
# 48  Relentless +,Tiki Taka,Slide Tackle,Long Shot ...
# 49  Power Header,Incisive Pass,First Touch,Relentl...
# 50  Rapid +,Power Shot,Flair,Quick Step,Long Shot ...
# 51  Relentless +,Whipped Cross,Rapid,Early Crosser...
# 52  Flair +,Finesse Shot,Dead Ball,Technical,First...
# 53  Whipped Cross,Block,Technical,Flair,First Touc...
# 54  Whipped Cross +,Dead Ball,Anticipate,Long Shot...
# 55    Long Ball Pass,Trivela,Long Shot Taker (CPU AI)
# 56  First Touch +,Finesse Shot,Technical,Flair,Lon...
# 57  Far Throw,Cross Claimer,Solid Player,Team Play...
# 58  Block +,Long Ball Pass,Slide Tackle,Long Shot ...
# 59  Incisive Pass,Press Proven,Long Shot Taker (CP...
#
# [60 rows x 76 columns]
